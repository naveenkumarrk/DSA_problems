# %% [markdown]
# 1- Given an array of 1s and 0s which has all 1s first followed by all 0s. Find the number of 0s.
#
#  Count the number of zeroes in the given array. Please try to solve it in O(log(n)).

# %%
nums = [1,1,1,1,0,0]

def first_zero(nums):
    n = len(nums)
    l = 0
    r = n-1
    while l<= r:
        mid = l + (r-l)//2
        if nums[mid] == 0:
            r = mid -1
        else:
            l = mid+1
    if l < n and nums[l] == 0:
        return n- l
    else:
        return 0
    
first_zero(nums)
# Out:
# 2

# %% [markdown]
# 2-  Given an integer X, find its square root. If X is not a perfect square, then return floor(√x). Do it in O(log(n)) time.

# %%
nums = 25

def non_perfect_sqr(num):
    return int(num ** (1/2))
non_perfect_sqr(nums)
# Out:
# 5

# %% [markdown]
# 3-  Reverse a Queue using Recursion.

# %%
from collections import deque

nums = deque()
nums.append(4)
nums.append(134)
nums.append(45)
nums.append(8)
nums.append(20)


def reverse_q(nums):
    n = len(nums)
    if n ==1:
        return nums[n]
    return reverse_q(nums)
reverse_q(nums)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [36], line 16
#      14         return nums[n]
#      15     return reverse_q(nums[n-1])
# ---> 16 reverse_q(nums)
#
# Cell In [36], line 15, in reverse_q(nums)
#      13 if n ==1:
#      14     return nums[n]
# ---> 15 return reverse_q(nums[n-1])
#
# Cell In [36], line 12, in reverse_q(nums)
#      11 def reverse_q(nums):
# ---> 12     n = len(nums)
#      13     if n ==1:
#      14         return nums[n]
#
# TypeError: object of type 'int' has no len()

# %% [markdown]
#  4- You are given two strings s and t.
#
#
# String t is generated by random shuffling string s and then add one more letter at a random position.
#
#
#
# Return the letter that was added to t
